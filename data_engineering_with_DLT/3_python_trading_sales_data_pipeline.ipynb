# %% [markdown]
# # Simplify ETL with Delta Live Table
#
# DLT makes Data Engineering accessible for all. Just declare your transformations in SQL or Python, and DLT will handle the Data Engineering complexity for you.
#
# <img style="float:right" src="https://github.com/QuentinAmbard/databricks-demo/raw/main/product_demos/dlt-golden-demo-loan-1.png" width="700"/>
#
# **Accelerate ETL development** <br/>
# Enable analysts and data engineers to innovate rapidly with simple pipeline development and maintenance
#
# **Remove operational complexity** <br/>
# By automating complex administrative tasks and gaining broader visibility into pipeline operations
#
# **Trust your data** <br/>
# With built-in quality controls and quality monitoring to ensure accurate and useful BI, Data Science, and ML
#
# **Simplify batch and streaming** <br/>
# With self-optimization and auto-scaling data pipelines for batch or streaming processing
#
# ## Our Delta Live Table pipeline
#
# Finally we will be using all the four data sources together and build one pipeline that
# - transforms all the data together
# - uses the FX rate to convert the pricing of the coal dataset (dataset_2.csv) to EUR.

# %% [markdown]
# The datasets we are going to use are the following:
#
# Feel free to choose on of the 4 CSV files that are available for a try-out:
# * dataset_1.csv -> Carbon emission trading specifically European Union Allowances (EUA)
# * dataset_2.csv -> Coal pricing for API 2
# * dataset_3.csv -> French electricity market, specifically focusing on power futures contracts
# * dataset_4.csv -> -	Foreign exchange (FX) rate information EUR-USD
#
# As a first step, we are going to ingest all the four datasets and create the corresponding bronze tables.
#
# We use the keyword `INCREMENTAL` and `stream()` to indicate we are incrementally loading data. Without `INCREMENTAL` you will scan and ingest all the data available at once.

# %%
import dlt
import pyspark.sql.functions as F
from pyspark.sql.functions import col, weekofyear, year, expr, round, avg, to_date, concat, lit, sum, window, date_format
from pyspark.sql import SparkSession
from pyspark.sql.window import Window

source = '/Volumes/dbw_databricks_dna_hackathon_databricks_stream/02_data_product_trading/data_volume/data/'

# %% [markdown]
# ### Bronze layer:
#
# <img style="float: left; padding-left: 10px" src="https://github.com/genseral/axpo_dna_summit_2024/blob/main/figures/Full_DLT_bronze.drawio.png?raw=true" width="600"/>

# %%
@dlt.table(
    name = "raw_CO2_EUA",
    comment = "Raw data from CO2_EUA",
)
@dlt.expect_or_fail("positive_settlement_price", F.col("settlement_price") > 0)
@dlt.expect_or_fail("traded_volume_null", (F.col("traded_volume") == 'NULL'))
@dlt.expect_or_fail("open_interest_null", (F.col("open_interest") == 'NULL'))
@dlt.expect_or_fail("block_volume_null", (F.col("Block_Volume") == 'NULL'))
@dlt.expect_or_fail("spread_volume_null", (F.col("Spread_Volume") == 'NULL'))
def raw_carbon_eua():
    return (
        spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("cloudFiles.inferColumnTypes", "true")
        .load(f"{source}dataset_1")
        .select("*")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>raw_CO2_EUA</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>settlement_price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>traded_volume</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>open_interest</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Block_Volume</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Spread_Volume</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AdjustedRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>_rescued_data</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    name = "raw_COAL_API2",
    comment = "Raw data from coal api2",
)
def raw_carbon_eua():
    return (
        spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("cloudFiles.inferColumnTypes", "true")
        .load(f"{source}dataset_2")
        .select("*")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>raw_COAL_API2</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AdjustedRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>_rescued_data</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    name = "raw_POWER_FRA",
    comment = "Raw data power data from france",
)
@dlt.expect_or_drop("vaild_volume", F.col("clearing_volume") != 'NULL')
def raw_carbon_eua():
    return (
        spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("cloudFiles.inferColumnTypes", "true")
        .load(f"{source}dataset_3")
        .select("*")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>raw_POWER_FRA</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>clearing_price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>clearing_volume</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AdjustedRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>_rescued_data</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    name = "raw_FX_EURUSD",
    comment = "Raw data for FX from euro to usd",
)
def raw_carbon_eua():
    return (
        spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "csv")
        .option("cloudFiles.inferColumnTypes", "true")
        .load(f"{source}dataset_4")
        .select("*")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>raw_FX_EURUSD</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>FX_Rate</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>AdjustedDeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>_rescued_data</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# ### Silver layer:
#
# <img style="float: left; padding-left: 10px" src="https://github.com/genseral/axpo_dna_summit_2024/blob/main/figures/Full_DLT_silver.drawio.png?raw=true" width="600"/>

# %%
@dlt.table(
    comment="Cleaned raw data for CO2 emissions from eua"
)
def silver_CO2_EUA():
    raw_co2_eua = dlt.read("raw_CO2_EUA")
    
    raw_co2_eua = raw_co2_eua.filter(F.col("DeliveryStartDate") <= F.col("DeliveryEndDate"))
    raw_co2_eua = raw_co2_eua.filter(F.col("DeliveryStartDate") == F.col("AdjustedDeliveryStartDate"))
    raw_co2_eua = raw_co2_eua.filter(F.col("DeliveryEndDate") == F.col("AdjustedDeliveryEndDate"))
    return (
        raw_co2_eua.select(
                col("TimeSeries_FID"),
                col("QuoteDateIndex_FID"),
                col("QuoteTime"),
                col("PublicationDateIndex_FID"),
                col("PublicationDate"),
                col("DeliveryGridPointName"),
                col("DeliveryStartDate"),
                col("DeliveryEndDate"),
                col("DeliveryRelativeBucketName"),
                col("DeliveryRelativeBucketNumber"),
                col("settlement_price"),
                col("Point_ID")
            )
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_CO2_EUA</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>settlement_price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    comment="Cleaned raw data for coal api2"
)
def silver_COAL_API2():
    raw_fx = dlt.read("raw_FX_EURUSD")
    raw_coal_api2 = dlt.read("raw_COAL_API2")
    
    raw_coal_api2 = raw_coal_api2.filter(F.col("DeliveryStartDate") <= F.col("DeliveryEndDate"))
    raw_coal_api2 = raw_coal_api2.filter(F.col("DeliveryStartDate") == F.col("AdjustedDeliveryStartDate"))
    raw_coal_api2 = raw_coal_api2.filter(F.col("DeliveryEndDate") == F.col("AdjustedDeliveryEndDate"))

    # First, fix the computation of the 'date' column to correctly use 'next_day'
    raw_fx_avg = raw_fx.withColumn("week", weekofyear("DeliveryStartDate")) \
                    .withColumn("year", year("DeliveryStartDate")) \
                    .groupBy("week", "year") \
                    .agg(round(avg("FX_Rate"), 2).alias("fx_rate_weekly_avg")) \
                    .withColumn("week_starting_sunday", expr("date_add(next_day(to_date(concat(year, '-01-01')), 'Sunday'), (week - 1) * 7)")) \
                    .withColumn("DeliveryStartDate", expr("date_sub(week_starting_sunday, 7)"))

    silver_coal_with_fx = raw_coal_api2.join(raw_fx_avg, on=['DeliveryStartDate'], how='left')
    silver_coal_with_fx = silver_coal_with_fx.withColumn('price_EUR', round(silver_coal_with_fx.price / silver_coal_with_fx.fx_rate_weekly_avg, 2))
    silver_coal_with_fx = silver_coal_with_fx.withColumnRenamed('price', 'price_USD')
    
    return silver_coal_with_fx.select(
        col("TimeSeries_FID"),
        col("PublicationDateIndex_FID"),
        col("PublicationDate"),
        col("QuoteDateIndex_FID"),
        col("QuoteTime"),
        col("DeliveryGridPointName"),
        col("DeliveryStartDate"),
        col("DeliveryEndDate"),
        col("DeliveryRelativeBucketName"),
        col("DeliveryRelativeBucketNumber"),
        col("price_EUR"),
        col("price_USD"),
        col("fx_rate_weekly_avg"),
        col("Point_ID")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_COAL_API2</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>price_EUR</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>price_USD</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>fx_rate_weekly_avg</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    comment="Cleaned raw power data from france"
)
def silver_POWER_FRA():
    raw_power_fra =  dlt.read("raw_POWER_FRA")

    raw_power_fra = raw_power_fra.filter(F.col("DeliveryStartDate") <= F.col("DeliveryEndDate"))
    raw_power_fra = raw_power_fra.filter(F.col("DeliveryStartDate") == F.col("AdjustedDeliveryStartDate"))
    raw_power_fra = raw_power_fra.filter(F.col("DeliveryEndDate") == F.col("AdjustedDeliveryEndDate"))
    
    return (
        raw_power_fra.select(
                col("TimeSeries_FID"),
                col("PublicationDateIndex_FID"),
                col("PublicationDate"),
                col("QuoteDateIndex_FID"),
                col("QuoteTime"),
                col("DeliveryGridPointName"),
                col("DeliveryStartDate"),
                col("DeliveryEndDate"),
                col("DeliveryRelativeBucketName"),
                col("DeliveryRelativeBucketNumber"),
                col("clearing_price"),
                col("clearing_volume"),
                col("Point_ID")
            )
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>process_raw_POWER_FRA_to_silver</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>clearing_price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>clearing_volume</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    comment="Cleaned FX rates"
)
def silver_FX_EURUSD():
    raw_FX_EURUSD =  dlt.read("raw_FX_EURUSD")

    raw_FX_EURUSD = raw_FX_EURUSD.filter(F.col("FX_RATE") > 0)
    raw_FX_EURUSD = raw_FX_EURUSD.filter(F.col("DeliveryStartDate") <= F.col("DeliveryEndDate"))
    raw_FX_EURUSD = raw_FX_EURUSD.filter(F.col("DeliveryStartDate") == F.col("AdjustedDeliveryStartDate"))
    raw_FX_EURUSD = raw_FX_EURUSD.filter(F.col("DeliveryEndDate") == F.col("AdjustedDeliveryEndDate"))

    return (
        raw_FX_EURUSD.select(
             col("TimeSeries_FID"),
             col("PublicationDateIndex_FID"),
             col("PublicationDate"),
             col("QuoteDateIndex_FID"),
             col("QuoteTime"),
             col("DeliveryGridPointName"),
             col("DeliveryStartDate"),
             col("DeliveryEndDate"),
             col("DeliveryRelativeBucketName"),
             col("DeliveryRelativeBucketNumber"),
             col("FX_Rate"),
             col("Point_ID")
            )
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_FX_EURUSD</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>FX_Rate</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# ### Gold layer:
#
# <img style="float: left; padding-left: 10px" src="https://github.com/genseral/axpo_dna_summit_2024/blob/main/figures/Full_DLT_gold.drawio.png?raw=true" width="600"/>

# %%
@dlt.table(
    comment="Aggregated CO2 EUA"
)
def gold_CO2_EUA():
    return (
        dlt.read("silver_CO2_EUA")
            .select(
            '*'
            )
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_silver_CO2_EUA</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>settlement_price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Fpython_trading_sales_data_pipeline&redirectNotebookId=2716391597893829">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    comment="Aggregated COAL API2"
)
def gold_COAL_API2():
    return (
        dlt.read("silver_COAL_API2")
            .select(
            '*'
            )
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_COAL_API2</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Ftrading_sales_data_pipeline&redirectNotebookId=2716391597703039">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    comment="Aggregated Power data from france"
)
def gold_POWER_FRA():
    return (
        dlt.read("silver_POWER_FRA")
            .select(
            '*'
            )
)
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_POWER_FRA</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>TimeSeries_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>PublicationDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>QuoteDateIndex_FID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>QuoteTime</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryGridPointName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryStartDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryEndDate</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketName</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>DeliveryRelativeBucketNumber</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>clearing_price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>clearing_volume</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Point_ID</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1444828305810485#joblist/pipelines/create?initialSource=%2FUsers%2Falexander.genser%40databricks.com%2FAXPO%2Fdna_summit%2FData_engineering_part%2Ftrading_sales_data_pipeline&redirectNotebookId=2716391597703039">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
    comment="Aggregated FX data from EURUSD"
)
def gold_FX_EURUSD():
    return (
        dlt.read("silver_FX_EURUSD")
            .select(
            '*'
            )
)
